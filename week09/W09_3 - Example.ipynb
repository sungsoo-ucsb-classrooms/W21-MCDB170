# %% [markdown]
# # Breast Cancer data

# %% [markdown]
# The breast cancer data was downloaded from [Link](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic) ). It is also included as [wdbc.data](wdbc.data).
#
# The description of the data can be found in [wdbc.names](wdbc.names).
#
# Try using other functions we learned in W09_2.
#
#
# <sub> Acknowledgement: Much of this ipynb is from [Link](https://towardsdatascience.com/pandas-for-biologists-f01c8a548b7c) </sub>

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd

bcd = pd.read_csv('wdbc.data')
bcd
# Out:
#        842302  M  17.99  10.38   122.8    1001   0.1184   0.2776   0.3001  \
# 0      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 1    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 2    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 3    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# 4      843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 563    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 564    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 565    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 566    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 567     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#       0.1471  ...   25.38  17.33   184.6    2019   0.1622   0.6656  0.7119  \
# 0    0.07017  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 1    0.12790  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 2    0.10520  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 3    0.10430  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# 4    0.08089  ...  15.470  23.75  103.40   741.6  0.17910  0.52490  0.5355
# ..       ...  ...     ...    ...     ...     ...      ...      ...     ...
# 563  0.13890  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 564  0.09791  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 565  0.05302  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 566  0.15200  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 567  0.00000  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#      0.2654  0.4601   0.1189
# 0    0.1860  0.2750  0.08902
# 1    0.2430  0.3613  0.08758
# 2    0.2575  0.6638  0.17300
# 3    0.1625  0.2364  0.07678
# 4    0.1741  0.3985  0.12440
# ..      ...     ...      ...
# 563  0.2216  0.2060  0.07115
# 564  0.1628  0.2572  0.06637
# 565  0.1418  0.2218  0.07820
# 566  0.2650  0.4087  0.12400
# 567  0.0000  0.2871  0.07039
#
# [568 rows x 32 columns]

# %%
bcd = pd.read_csv('wdbc.data', header = None, usecols=np.arange(12))
bcd
# Out:
#            0  1      2      3       4       5        6        7        8   \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#           9       10       11
# 0    0.14710  0.2419  0.07871
# 1    0.07017  0.1812  0.05667
# 2    0.12790  0.2069  0.05999
# 3    0.10520  0.2597  0.09744
# 4    0.10430  0.1809  0.05883
# ..       ...     ...      ...
# 564  0.13890  0.1726  0.05623
# 565  0.09791  0.1752  0.05533
# 566  0.05302  0.1590  0.05648
# 567  0.15200  0.2397  0.07016
# 568  0.00000  0.1587  0.05884
#
# [569 rows x 12 columns]

# %%
bcd = pd.read_csv('wdbc.data', header = None, usecols=np.arange(12), index_col=0)
bcd
# Out:
#          1      2      3       4       5        6        7        8        9   \
# 0
# 842302    M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 842517    M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ...      ..    ...    ...     ...     ...      ...      ...      ...      ...
# 926424    M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 926682    M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 926954    M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 927241    M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 92751     B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
#               10       11
# 0
# 842302    0.2419  0.07871
# 842517    0.1812  0.05667
# 84300903  0.2069  0.05999
# 84348301  0.2597  0.09744
# 84358402  0.1809  0.05883
# ...          ...      ...
# 926424    0.1726  0.05623
# 926682    0.1752  0.05533
# 926954    0.1590  0.05648
# 927241    0.2397  0.07016
# 92751     0.1587  0.05884
#
# [569 rows x 11 columns]

# %%
bcd.columns = [ 'Diagnosis', 'Radius','Texture', 'Perimeter', 'Area', 'Smoothness',
              'Compactness','Concavity','Concave points','Symmetry','Fractal dimension']
bcd.index.name = 'ID'
bcd.head()
# Out:
#          Diagnosis  Radius  Texture  Perimeter    Area  Smoothness  \
# ID
# 842302           M   17.99    10.38     122.80  1001.0     0.11840
# 842517           M   20.57    17.77     132.90  1326.0     0.08474
# 84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 84348301         M   11.42    20.38      77.58   386.1     0.14250
# 84358402         M   20.29    14.34     135.10  1297.0     0.10030
#
#           Compactness  Concavity  Concave points  Symmetry  Fractal dimension
# ID
# 842302        0.27760     0.3001         0.14710    0.2419            0.07871
# 842517        0.07864     0.0869         0.07017    0.1812            0.05667
# 84300903      0.15990     0.1974         0.12790    0.2069            0.05999
# 84348301      0.28390     0.2414         0.10520    0.2597            0.09744
# 84358402      0.13280     0.1980         0.10430    0.1809            0.05883

# %%
bcd.tail()
# Out:
#        Diagnosis  Radius  Texture  Perimeter    Area  Smoothness  Compactness  \
# ID
# 926424         M   21.56    22.39     142.00  1479.0     0.11100      0.11590
# 926682         M   20.13    28.25     131.20  1261.0     0.09780      0.10340
# 926954         M   16.60    28.08     108.30   858.1     0.08455      0.10230
# 927241         M   20.60    29.33     140.10  1265.0     0.11780      0.27700
# 92751          B    7.76    24.54      47.92   181.0     0.05263      0.04362
#
#         Concavity  Concave points  Symmetry  Fractal dimension
# ID
# 926424    0.24390         0.13890    0.1726            0.05623
# 926682    0.14400         0.09791    0.1752            0.05533
# 926954    0.09251         0.05302    0.1590            0.05648
# 927241    0.35140         0.15200    0.2397            0.07016
# 92751     0.00000         0.00000    0.1587            0.05884

# %%
bcd.describe()
# Out:
#            Radius     Texture   Perimeter         Area  Smoothness  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#        Compactness   Concavity  Concave points    Symmetry  Fractal dimension
# count   569.000000  569.000000      569.000000  569.000000         569.000000
# mean      0.104341    0.088799        0.048919    0.181162           0.062798
# std       0.052813    0.079720        0.038803    0.027414           0.007060
# min       0.019380    0.000000        0.000000    0.106000           0.049960
# 25%       0.064920    0.029560        0.020310    0.161900           0.057700
# 50%       0.092630    0.061540        0.033500    0.179200           0.061540
# 75%       0.130400    0.130700        0.074000    0.195700           0.066120
# max       0.345400    0.426800        0.201200    0.304000           0.097440

# %%
bcd.corr()
# Out:
#                      Radius   Texture  Perimeter      Area  Smoothness  \
# Radius             1.000000  0.323782   0.997855  0.987357    0.170581
# Texture            0.323782  1.000000   0.329533  0.321086   -0.023389
# Perimeter          0.997855  0.329533   1.000000  0.986507    0.207278
# Area               0.987357  0.321086   0.986507  1.000000    0.177028
# Smoothness         0.170581 -0.023389   0.207278  0.177028    1.000000
# Compactness        0.506124  0.236702   0.556936  0.498502    0.659123
# Concavity          0.676764  0.302418   0.716136  0.685983    0.521984
# Concave points     0.822529  0.293464   0.850977  0.823269    0.553695
# Symmetry           0.147741  0.071401   0.183027  0.151293    0.557775
# Fractal dimension -0.311631 -0.076437  -0.261477 -0.283110    0.584792
#
#                    Compactness  Concavity  Concave points  Symmetry  \
# Radius                0.506124   0.676764        0.822529  0.147741
# Texture               0.236702   0.302418        0.293464  0.071401
# Perimeter             0.556936   0.716136        0.850977  0.183027
# Area                  0.498502   0.685983        0.823269  0.151293
# Smoothness            0.659123   0.521984        0.553695  0.557775
# Compactness           1.000000   0.883121        0.831135  0.602641
# Concavity             0.883121   1.000000        0.921391  0.500667
# Concave points        0.831135   0.921391        1.000000  0.462497
# Symmetry              0.602641   0.500667        0.462497  1.000000
# Fractal dimension     0.565369   0.336783        0.166917  0.479921
#
#                    Fractal dimension
# Radius                     -0.311631
# Texture                    -0.076437
# Perimeter                  -0.261477
# Area                       -0.283110
# Smoothness                  0.584792
# Compactness                 0.565369
# Concavity                   0.336783
# Concave points              0.166917
# Symmetry                    0.479921
# Fractal dimension           1.000000

# %%
bcd.columns
# Out:
# Index(['Diagnosis', 'Radius', 'Texture', 'Perimeter', 'Area', 'Smoothness',
#        'Compactness', 'Concavity', 'Concave points', 'Symmetry',
#        'Fractal dimension'],
#       dtype='object')

# %%
bcd.shape
# Out:
# (569, 11)

# %%
sub = bcd.loc[bcd["Diagnosis"] == 'M', ["Diagnosis","Compactness", "Perimeter"]]
sub
# Out:
#          Diagnosis  Compactness  Perimeter
# ID
# 842302           M      0.27760     122.80
# 842517           M      0.07864     132.90
# 84300903         M      0.15990     130.00
# 84348301         M      0.28390      77.58
# 84358402         M      0.13280     135.10
# ...            ...          ...        ...
# 926125           M      0.22360     143.00
# 926424           M      0.11590     142.00
# 926682           M      0.10340     131.20
# 926954           M      0.10230     108.30
# 927241           M      0.27700     140.10
#
# [212 rows x 3 columns]

# %%
sub.drop("Compactness", axis=1)
# Out:
#          Diagnosis  Perimeter
# ID
# 842302           M     122.80
# 842517           M     132.90
# 84300903         M     130.00
# 84348301         M      77.58
# 84358402         M     135.10
# ...            ...        ...
# 926125           M     143.00
# 926424           M     142.00
# 926682           M     131.20
# 926954           M     108.30
# 927241           M     140.10
#
# [212 rows x 2 columns]

# %%
sub
# Out:
#          Diagnosis  Compactness  Perimeter
# ID
# 842302           M      0.27760     122.80
# 842517           M      0.07864     132.90
# 84300903         M      0.15990     130.00
# 84348301         M      0.28390      77.58
# 84358402         M      0.13280     135.10
# ...            ...          ...        ...
# 926125           M      0.22360     143.00
# 926424           M      0.11590     142.00
# 926682           M      0.10340     131.20
# 926954           M      0.10230     108.30
# 927241           M      0.27700     140.10
#
# [212 rows x 3 columns]

# %%
sub.loc[927241, 'Compactness']    # This is the most desirable indexing method
                                  # Other methods below work, but not easily readable.
# Out:
# 0.27699999999999997

# %%
sub.loc[927241]['Compactness']
# Out:
# 0.27699999999999997

# %%
sub['Compactness'].loc[927241]
# Out:
# 0.27699999999999997

# %%
sub.drop(926682, axis=0)  # 566 is not the row number, but the ID of the row
# Out:
#          Diagnosis  Compactness  Perimeter
# ID
# 842302           M      0.27760     122.80
# 842517           M      0.07864     132.90
# 84300903         M      0.15990     130.00
# 84348301         M      0.28390      77.58
# 84358402         M      0.13280     135.10
# ...            ...          ...        ...
# 925622           M      0.20870     103.40
# 926125           M      0.22360     143.00
# 926424           M      0.11590     142.00
# 926954           M      0.10230     108.30
# 927241           M      0.27700     140.10
#
# [211 rows x 3 columns]

# %%
sub.to_csv('test.csv')

# %%
sub.assign(a_name_for_new_column = sub.sum(axis=1))
# Out:
#          Diagnosis  Compactness  Perimeter  a_name_for_new_column
# ID
# 842302           M      0.27760     122.80              123.07760
# 842517           M      0.07864     132.90              132.97864
# 84300903         M      0.15990     130.00              130.15990
# 84348301         M      0.28390      77.58               77.86390
# 84358402         M      0.13280     135.10              135.23280
# ...            ...          ...        ...                    ...
# 926125           M      0.22360     143.00              143.22360
# 926424           M      0.11590     142.00              142.11590
# 926682           M      0.10340     131.20              131.30340
# 926954           M      0.10230     108.30              108.40230
# 927241           M      0.27700     140.10              140.37700
#
# [212 rows x 4 columns]

# %%
bcd_2 = bcd.copy()
bcd_2['Diagnosis'] = bcd_2['Diagnosis'].replace(to_replace=['M','B'], value=['Malign', 'Benign'])
bcd_2
# Out:
#          Diagnosis  Radius  Texture  Perimeter    Area  Smoothness  \
# ID
# 842302      Malign   17.99    10.38     122.80  1001.0     0.11840
# 842517      Malign   20.57    17.77     132.90  1326.0     0.08474
# 84300903    Malign   19.69    21.25     130.00  1203.0     0.10960
# 84348301    Malign   11.42    20.38      77.58   386.1     0.14250
# 84358402    Malign   20.29    14.34     135.10  1297.0     0.10030
# ...            ...     ...      ...        ...     ...         ...
# 926424      Malign   21.56    22.39     142.00  1479.0     0.11100
# 926682      Malign   20.13    28.25     131.20  1261.0     0.09780
# 926954      Malign   16.60    28.08     108.30   858.1     0.08455
# 927241      Malign   20.60    29.33     140.10  1265.0     0.11780
# 92751       Benign    7.76    24.54      47.92   181.0     0.05263
#
#           Compactness  Concavity  Concave points  Symmetry  Fractal dimension
# ID
# 842302        0.27760    0.30010         0.14710    0.2419            0.07871
# 842517        0.07864    0.08690         0.07017    0.1812            0.05667
# 84300903      0.15990    0.19740         0.12790    0.2069            0.05999
# 84348301      0.28390    0.24140         0.10520    0.2597            0.09744
# 84358402      0.13280    0.19800         0.10430    0.1809            0.05883
# ...               ...        ...             ...       ...                ...
# 926424        0.11590    0.24390         0.13890    0.1726            0.05623
# 926682        0.10340    0.14400         0.09791    0.1752            0.05533
# 926954        0.10230    0.09251         0.05302    0.1590            0.05648
# 927241        0.27700    0.35140         0.15200    0.2397            0.07016
# 92751         0.04362    0.00000         0.00000    0.1587            0.05884
#
# [569 rows x 11 columns]

# %%
bcd
# Out:
#          Diagnosis  Radius  Texture  Perimeter    Area  Smoothness  \
# ID
# 842302           M   17.99    10.38     122.80  1001.0     0.11840
# 842517           M   20.57    17.77     132.90  1326.0     0.08474
# 84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 84348301         M   11.42    20.38      77.58   386.1     0.14250
# 84358402         M   20.29    14.34     135.10  1297.0     0.10030
# ...            ...     ...      ...        ...     ...         ...
# 926424           M   21.56    22.39     142.00  1479.0     0.11100
# 926682           M   20.13    28.25     131.20  1261.0     0.09780
# 926954           M   16.60    28.08     108.30   858.1     0.08455
# 927241           M   20.60    29.33     140.10  1265.0     0.11780
# 92751            B    7.76    24.54      47.92   181.0     0.05263
#
#           Compactness  Concavity  Concave points  Symmetry  Fractal dimension
# ID
# 842302        0.27760    0.30010         0.14710    0.2419            0.07871
# 842517        0.07864    0.08690         0.07017    0.1812            0.05667
# 84300903      0.15990    0.19740         0.12790    0.2069            0.05999
# 84348301      0.28390    0.24140         0.10520    0.2597            0.09744
# 84358402      0.13280    0.19800         0.10430    0.1809            0.05883
# ...               ...        ...             ...       ...                ...
# 926424        0.11590    0.24390         0.13890    0.1726            0.05623
# 926682        0.10340    0.14400         0.09791    0.1752            0.05533
# 926954        0.10230    0.09251         0.05302    0.1590            0.05648
# 927241        0.27700    0.35140         0.15200    0.2397            0.07016
# 92751         0.04362    0.00000         0.00000    0.1587            0.05884
#
# [569 rows x 11 columns]

# %%
bcd_2["Diagnosis"].value_counts()
# Out:
# Benign    357
# Malign    212
# Name: Diagnosis, dtype: int64

# %%
bcd_2["Diagnosis"].value_counts(normalize = True)
# Out:
# Benign    0.627417
# Malign    0.372583
# Name: Diagnosis, dtype: float64

# %%
bcd.groupby('Diagnosis').describe()
# Out:
#           Radius                                                             \
#            count       mean       std     min     25%     50%    75%    max
# Diagnosis
# B          357.0  12.146524  1.780512   6.981  11.080  12.200  13.37  17.85
# M          212.0  17.462830  3.203971  10.950  15.075  17.325  19.59  28.11
#
#           Texture             ... Symmetry         Fractal dimension  \
#             count       mean  ...      75%     max             count
# Diagnosis                     ...
# B           357.0  17.914762  ...  0.18900  0.2743             357.0
# M           212.0  21.604906  ...  0.20985  0.3040             212.0
#
#
#                mean       std      min       25%       50%       75%      max
# Diagnosis
# B          0.062867  0.006747  0.05185  0.058530  0.061540  0.065760  0.09575
# M          0.062680  0.007573  0.04996  0.056598  0.061575  0.067075  0.09744
#
# [2 rows x 80 columns]

# %%
bcd.groupby('Diagnosis')['Radius'].describe()
# Out:
#            count       mean       std     min     25%     50%    75%    max
# Diagnosis
# B          357.0  12.146524  1.780512   6.981  11.080  12.200  13.37  17.85
# M          212.0  17.462830  3.203971  10.950  15.075  17.325  19.59  28.11

# %%
bcd.groupby('Diagnosis').describe()['Radius']
# Out:
#            count       mean       std     min     25%     50%    75%    max
# Diagnosis
# B          357.0  12.146524  1.780512   6.981  11.080  12.200  13.37  17.85
# M          212.0  17.462830  3.203971  10.950  15.075  17.325  19.59  28.11

# %% [markdown]
# # Visualization
#
# Pandas' default is matplotlib.

# %%
bcd.plot(kind = 'scatter', x = 'Radius', y = 'Texture')

# %%
# Tricks to vary the dot properties in a scatter plot

size = bcd.Radius**2  # The size of dots will follow the square of Radius.
color = np.where(bcd.Diagnosis == 'M',  'blue', 'orange')  # Check the "where()" function in numpy

bcd.plot.scatter(x='Radius',y='Texture',s = size,c=color)   # This uses a large dots for all data points with year is 10's multiple

# %%
bcd.plot(kind = 'hist', y = 'Radius')

# %%
bcd[['Radius', 'Texture']].plot(kind = 'hist', alpha = 0.6)

# %%
bcd[['Radius', 'Texture']].plot(kind = 'density', bw_method = 0.5)  # bw_method: smoothing factor

# %%
bcd[['Radius', 'Texture']].plot(kind = 'box')

# %% [markdown]
# ## Seaborn
#
# If you want more modern figures, try Seaborn. [Seaborn website](https://seaborn.pydata.org/examples/index.html)
#
# Below are a couple of examples.

# %%
import seaborn as sns

sns.heatmap(bcd.corr(), cmap='Blues', linewidth=0.5)

# %%
sns.heatmap(bcd.groupby('Diagnosis').corr())

# %%
sub = bcd.loc[:, ['Diagnosis', 'Radius', 'Perimeter', 'Smoothness']]
sns.pairplot(sub, hue = 'Diagnosis')
